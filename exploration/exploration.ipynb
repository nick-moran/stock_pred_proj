# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import os
from dateutil import parser

# %%
files = os.listdir('../charts')

# %%
aapl1440 = pd.read_csv('../charts/APPLE1440.csv')

aaple_m1 = aapl1440[aapl1440['date'].str.contains('2018.01.', na=False)]
aaple_m1
# Out:
#            date   time    open    high     low   close  unknown
# 870  2018-01-02  00:00  169.99  172.24  169.25  172.09    41108
# 871  2018-01-03  00:00  172.50  174.54  171.83  171.85    43686
# 872  2018-01-04  00:00  172.75  173.46  172.07  173.16    41074
# 873  2018-01-05  00:00  173.54  175.21  173.03  174.95    43982
# 874  2018-01-08  00:00  174.53  175.57  173.91  174.17    40778
# 875  2018-01-09  00:00  174.60  175.04  173.37  174.02    47565
# 876  2018-01-10  00:00  173.15  174.28  172.97  174.08    49174
# 877  2018-01-11  00:00  174.63  175.47  174.37  175.24    41227
# 878  2018-01-12  00:00  176.31  177.33  175.58  176.98    48792
# 879  2018-01-16  00:00  178.27  179.38  176.12  176.19    64553
# 880  2018-01-17  00:00  175.30  179.24  175.05  179.13    58689
# 881  2018-01-18  00:00  179.08  180.09  178.22  178.85    54887
# 882  2018-01-19  00:00  178.81  179.55  177.39  178.45    49192
# 883  2018-01-22  00:00  177.38  177.77  176.60  177.09    44262
# 884  2018-01-23  00:00  177.59  179.43  176.49  176.65    54763
# 885  2018-01-24  00:00  177.59  177.90  173.18  174.18    65992
# 886  2018-01-25  00:00  174.90  175.04  170.51  171.30    64700
# 887  2018-01-26  00:00  172.08  172.30  170.03  171.40    59291
# 888  2018-01-29  00:00  170.29  170.31  167.04  167.90    56798
# 889  2018-01-30  00:00  166.01  167.36  164.69  167.05    64970
# 890  2018-01-31  00:00  166.55  168.43  166.33  166.56    56353

# %%
def filter_articles(news_dir):
  news_files = os.listdir(news_dir)

  news_info = []
  for file in news_files:
      with open(f'./{news_dir}/{file}') as article:
        article_content = json.load(article)
        aapl = -1
        amzn = -1
        if article_content['language'] == 'english':
        # for org in article_content['entities']['organizations']:
          # if ('apple' in article_content['text'].lower()) and aapl < 0:
          news_info.append(['aapl', article_content['published'], article_content['text'], f'{news_dir}/{file}'])
            # aapl *= -1

          # if ('amazon' in article_content['text'].lower()) and amzn < 0:
          #   news_info.append(['amzn', article_content['published'], article_content['text'], f'{news_dir}/{file}'])
          #   amzn *= -1
  return news_info

# %%
news_dirs = os.listdir('../news')

ndf= []
for news_dir in news_dirs:
    ndf.extend(filter_articles(f'../news/{news_dir}'))

print(len(ndf))
# Out:
# 70732

# %%
news_data = pd.DataFrame(ndf, columns=['company', 'date','text','file'])
news_data
# Out:
#       company                           date  \
# 0        aapl  2018-08-13T03:00:00.000+03:00
# 1        aapl  2018-08-31T12:13:00.000+03:00
# 2        aapl  2018-08-27T22:27:00.000+03:00
# 3        aapl  2018-08-02T02:01:00.000+03:00
# 4        aapl  2018-08-19T23:00:00.000+03:00
# ...       ...                            ...
# 70727    aapl  2018-12-27T02:23:00.000+02:00
# 70728    aapl  2018-12-13T16:46:00.000+02:00
# 70729    aapl  2018-12-06T02:00:00.000+02:00
# 70730    aapl  2018-12-14T16:44:00.000+02:00
# 70731    aapl  2018-12-04T20:00:00.000+02:00
#
#                                                     text  \
# 0      \nKAYLA TAUSCHE, NIGHTLY BUSINESS REPORT CORRE...
# 1      \nEdgewood Management LLC lowered its stake in...
# 2      Dow jumps more than 250 points, Nasdaq hits 8,...
# 3      South Korea Market May Give Up Support At 2,30...
# 4      Tim Cook apps More Justin Sullivan/Getty Image...
# ...                                                  ...
# 70727  Google's Hardware Ambitions Are Starting to Pa...
# 70728  ETF Preview: ETFs, Futures Point Higher as Str...
# 70729  After a one-day break, the stock market contin...
# 70730  \nLaurel Wealth Advisors Inc. lifted its posit...
# 70731  BY THE NUMBERS U.S. stock futures were lower t...
#
#                                                     file
# 0      ../news/2018_08_d157b48c57be246ec7dd80e7af4388...
# 1      ../news/2018_08_d157b48c57be246ec7dd80e7af4388...
# 2      ../news/2018_08_d157b48c57be246ec7dd80e7af4388...
# 3      ../news/2018_08_d157b48c57be246ec7dd80e7af4388...
# 4      ../news/2018_08_d157b48c57be246ec7dd80e7af4388...
# ...                                                  ...
# 70727  ../news/2018_12_d157b48c57be246ec7dd80e7af4388...
# 70728  ../news/2018_12_d157b48c57be246ec7dd80e7af4388...
# 70729  ../news/2018_12_d157b48c57be246ec7dd80e7af4388...
# 70730  ../news/2018_12_d157b48c57be246ec7dd80e7af4388...
# 70731  ../news/2018_12_d157b48c57be246ec7dd80e7af4388...
#
# [70732 rows x 4 columns]

# %%
news_data['date'] = pd.to_datetime(news_data['date'], utc=True)
news_dates = news_data['date'].dt.date
news_times = news_data['date'].dt.time

news_data['date'] = news_dates
news_data['time'] = news_times

# %%
news_data = news_data.drop_duplicates(subset=['text'])
news_data = news_data[news_data['text'] != ' ']
news_data
# Out:
#       company        date                                               text  \
# 0        aapl  2018-08-13  \nKAYLA TAUSCHE, NIGHTLY BUSINESS REPORT CORRE...
# 1        aapl  2018-08-31  \nEdgewood Management LLC lowered its stake in...
# 2        aapl  2018-08-27  Dow jumps more than 250 points, Nasdaq hits 8,...
# 3        aapl  2018-08-01  South Korea Market May Give Up Support At 2,30...
# 4        aapl  2018-08-19  Tim Cook apps More Justin Sullivan/Getty Image...
# ...       ...         ...                                                ...
# 70727    aapl  2018-12-27  Google's Hardware Ambitions Are Starting to Pa...
# 70728    aapl  2018-12-13  ETF Preview: ETFs, Futures Point Higher as Str...
# 70729    aapl  2018-12-06  After a one-day break, the stock market contin...
# 70730    aapl  2018-12-14  \nLaurel Wealth Advisors Inc. lifted its posit...
# 70731    aapl  2018-12-04  BY THE NUMBERS U.S. stock futures were lower t...
#
#                                                     file      time
# 0      ../news/2018_08_d157b48c57be246ec7dd80e7af4388...  00:00:00
# 1      ../news/2018_08_d157b48c57be246ec7dd80e7af4388...  09:13:00
# 2      ../news/2018_08_d157b48c57be246ec7dd80e7af4388...  19:27:00
# 3      ../news/2018_08_d157b48c57be246ec7dd80e7af4388...  23:01:00
# 4      ../news/2018_08_d157b48c57be246ec7dd80e7af4388...  20:00:00
# ...                                                  ...       ...
# 70727  ../news/2018_12_d157b48c57be246ec7dd80e7af4388...  00:23:00
# 70728  ../news/2018_12_d157b48c57be246ec7dd80e7af4388...  14:46:00
# 70729  ../news/2018_12_d157b48c57be246ec7dd80e7af4388...  00:00:00
# 70730  ../news/2018_12_d157b48c57be246ec7dd80e7af4388...  14:44:00
# 70731  ../news/2018_12_d157b48c57be246ec7dd80e7af4388...  18:00:00
#
# [67581 rows x 5 columns]

# %%
from collections import Counter

# %%
c = Counter(news_data['text'])
c.most_common(2)
# Out:
# [('\nNYDOW;25326.16;-7.66Nasdaq;7802.69;+95.40CME225;22575;+65(大証比)\n[NY市場データ]\n2日のNY市場はまちまち。ダウ平均は7.66ドル安の25326.16、ナスダックは95.40ポイント高の7802.69で取引を終了した。米中貿易摩擦への警戒感からアジア・欧州株が全面安となり、売りが先行したものの、携帯端末のアップル(AAPL)の決算が引き続き好感され、主要ハイテク株に幅広く買いが広がる展開となった。セクター別では、テクノロジー・ハード・機器や家庭・パーソナル用品が上昇する一方でメディアや素材が下落した。シカゴ日経225先物清算値は大阪比65円高の22575円。ADRの日本株はトヨタ<7203>、ＮＴＴ<9432>、ソフトバンクＧ<9984>、ファナック<6954>、ソニー<6758>、三井住友<8316>、任天堂<7974>、ファーストリテ<9983>など、対東証比較（1ドル111.64円換算）で全般堅調。《TM》\nスポンサードリンク ',
#   1),
#  ('\nKAYLA TAUSCHE, NIGHTLY BUSINESS REPORT CORRESPONDENT: The tweet from President Trump sent shock waves through the market. The president suggesting tariffs of 20 percent on aluminum and 50 percent on steel, just for Turkey, calling relations not good. The informal order coming as tensions between the two countries boiled over, causing a steep drop in Turkey`s currency and a call from Turkey`s president that it would prevail in what he called an economic war, hiking tariffs which Turkey says is illegal and potentially salt in the wound.\nROBERT HORMATS, FORMER STATE DEPARTMENT OFFICIAL: This does create more problem, and I think that`s what troubles the market so much. It`s not just what`s happened. It`s the fact that the two leaders are now trying to work out something to dampen down the problem. They`re, in fact, taking measures to exacerbate it.\nTAUSCHE: The company buying steel and aluminum from Turkey are now caught in the middle of the mayhem.\nFrank Bergren runs Metal Partners International which processes and distributes rebar. We first spoke with him in July as he faced rising bills from tariffs on European partners.\nFRANK BERGREN, METAL PARTNERS INTERNATIONAL CEO: I would buy all my steel from domestic mills if I had the option. The reality is, is that the capacity isn`t the place to need it.\nTAUSCHE: Today, Bergren has cargo from Turkey on its way to Houston. He says his Turkish supplier is in an array of panic at the moment. Neither side sure what that steel will cost when it gets there or what this escalation means for future business.\nFor NIGHTLY BUSINESS REPORT, I`m Kayla Tausche in Washington.\n(END VIDEOTAPE)\nGRIFFETH: As we mentioned, the drama in Turkey rattled investors here in the U.S. today. Adding to those jitters, inflation. Consumer prices rose slightly last month, but the 12-month core reading rose nearly 2.5 percent. That was the most we`ve seen in nearly a decade.\nStocks did come off their low, but it was still a Friday solidly in the red. The Dow was down 196 points when the bell rang at 25,313. The Nasdaq fell by 52, snapping its eight-day win streak, and the S&P was off by 20. For the week, the Nasdaq was the only positive index.\nSeema Mody has more on today`s action.\n(BEGIN VIDEOTAPE)\nSEEMA MODY, NIGHTLY BUSINESS REPORT CORRESPONDENT: Financial affairs swirling around Turkey shook up global markets today after the Turkish lira plummeted 20 percent to a record low against the U.S. dollar. Financials lag on the session, banking stocks like Goldman Sachs (NYSE:GS) and J.P. Morgan took a hit on fears that Turkey`s financial crisis could spill over into the global banking space. Bond yields also tumbled to session lows as investors poured money into treasuries in a flight to safety play, and gold prices got a bit, but ended lower on the week.\nThe big question on the trading floor is what international risks mean for Fed policy. Today`s latest read on inflation looks like it would put the Fed on course to continue raising rates. But that would push the dollar even higher against the Turkish lira, further exacerbating Turkey`s financial woes.\nPresident Donald Trump added fuel to the fire, announcing he would double Turkey`s metal tariffs as the lira remains in a free fall. Industrial stocks took a hit on that news. Remember, manufacturing giants like Boeing (NYSE:BA) and Caterpillar (NYSE:CAT) are often seen as classic proxies for trade war concerns.\nFor NIGHTLY BUSINESS REPORT, I`m Seema Mody at the New York Stock Exchange.\n(END VIDEOTAPE)\nHERERA: Let`s turn now to Art Hogan for more on Turkey and why we should care about what`s happening in that part of the world. He is chief market strategist at F — B. Riley FBR.\nGood to see you again, Art. Welcome back.\nART HOGAN, CHIEF MARKET STRATEGIST, B. RILEY FBR: Thanks, Sue. Great to see you.\nHERERA: It`s good to see you.\nLet`s talk about strategically how important Turkey is and there are those who think that this maybe the beginning of ...
#   1)]

# %%
news_data.to_csv('news_data_unique.csv',index=False)

# %%
apple_news = news_data[news_data['company'] == 'aapl']

# %%
aapl1440['date'] = aapl1440['date'].apply(lambda x: x.replace('.', '-'))
stock = aapl1440[aapl1440['date'] >= '2018-01-01'][['date', 'open']]
stock['open'] = stock['open'].astype(float)
stock['date'] = pd.to_datetime(stock['date'])

stock=stock.set_index('date')
stock

# %%
apple_news_days = apple_news[apple_news['date'] >= pd.Timestamp('2018-01-01')].groupby(by=['date']).count()
# apple_news.iloc[0]
apple_news_days

# %%
dates = np.zeros((len(apple_news_days) ,2),dtype=object)
dates[:,0] = np.arange(np.datetime64("2018-01-01"), np.datetime64("2019-02-08"), np.timedelta64(1, "D"))

# print(dates)
dates_df = pd.DataFrame(dates,columns=['date', 'dummy'])
dates_df['date'] = pd.to_datetime(dates_df['date'])
dates_df=dates_df.set_index('date')
dates_df

# %%
dates_df.index

# %%
stock.index

# %%
dates_df = dates_df.join(stock)

# %%
dates_df = dates_df.join(apple_news_days)
dates_df = dates_df.dropna()
dates_df

# %%
# plt.plot(dates_df['open'])
# plt.bar(dates_df.index,dates_df['company'])

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('apple stock')
ax1.set_ylabel('price', color=color)
ax1.plot(dates_df.index, dates_df['open'], color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('number of news articles', color=color)  # we already handled the x-label with ax1
ax2.bar(dates_df.index,dates_df['company'], color=color, alpha=0.7)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title('apple stock price with number of news articles')
plt.show()
